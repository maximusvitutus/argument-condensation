# %%
import os
import sys
import re
# Get the absolute path to the parent directory (assumes this file is in 'condensation')
parent_dir = os.path.abspath(os.path.join(os.getcwd(), '..'))
sys.path.insert(0, parent_dir)
# autoreload modules
# %load_ext autoreload
# %autoreload 2
from typing import List
import pandas as pd
from chatbot_api.providers.openai import OpenAIProvider
from chatbot_api.base import Role, Message
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
class Argument:
    def __init__(self, main_point: str, subpoints: List[str], score_distribution: List[int], source_indices: List[int]):
        self.main_point = main_point
        self.subpoints = subpoints
        self.score_distribution = score_distribution
        self.source_indices = source_indices

class ArgumentProcessor:
    def __init__(self, llm_provider: OpenAIProvider, batch_size: int):
        self.llm_provider = llm_provider
        self.batch_size = batch_size
        self.PROMPT_TEMPLATE = """
            ### Instructions:
            1. Review the following numbered comments on the topic: "{topic}"
            2. **Identify and categorize arguments into main topics**.
                - Main arguments are broad, high-level points.
                - Subpoints provide supporting details or reasoning for the main argument.
            3. Avoid redundancy by combining similar arguments or subpoints.
            4. For each argument and subpoint, include the indices of the source comments in square brackets, as shown in the output format below.
            5. Ensure each argument includes source indices which keep track of the comments that support the argument.
            6. Provide the output in Finnish.
            7. Ensure that no argument is repeated, and that each is categorized correctly, avoiding redundancy.
            
            ### Output Format: 
            <ARGUMENTS>
            MAIN: [Main Argument] [source_indices: 1,2,3]
            SUB: [Supporting subpoint] [source_indices: 1,2]
            SUB: [Another supporting subpoint] [source_indices: 3]
            </ARGUMENTS>

            ### Comments to analyze:
            {comments_text}
            """

    def get_relevant_scores(self, indices: List[int], all_likert_scores: List[int]) -> List[int]:
        """
        Get the Likert scores for the given indices from the full list of scores.
        
        Args:
            indices: List of indices for which to get scores
            all_likert_scores: Complete list of Likert scores
            
        Returns:
            List of Likert scores corresponding to the given indices
        """
        return [all_likert_scores[idx] for idx in indices if idx < len(all_likert_scores)]

    def calculate_score_distribution(self, scores: List[int]) -> List[int]:
        """
        Calculate the distribution of Likert scores (as percentages).
        
        Args:
            scores: List of Likert scores (1-5)
            
        Returns:
            List of 5 ints representing the percentage distribution of scores
        """
        if not scores:
            return [0] * 5
            
        distribution = [0] * 5
        for score in scores:
            if 1 <= score <= 5:  # Assuming Likert scale 1-5
                distribution[int(score-1)] += 1
                
        total = sum(distribution)
        return [count for count in distribution] if total > 0 else [0] * 5

    async def _create_initial_prompt(self, comments: List[str], indices: List[int], topic: str) -> str:
        """
        Create the initial prompt for the argument generation task with max number of comments that fit in the prompt.
        Returns the prompt and the number of comments that fit in the prompt.
        """

        fit_count = await self.llm_provider.fit_comment_args_count(comments, self.PROMPT_TEMPLATE.format(topic=topic, comments_text="")) # populate with topic and dummy comment text
        
        if fit_count == 0:
            raise ValueError("No comments fit in the prompt.")

        # Take only the messages that fit
        comments = comments[:fit_count]
        indices = indices[:fit_count]

        numbered_comments = [f"[{idx}] {comment}" for idx, comment in zip(indices, comments)]
        comments_text = "\n".join(numbered_comments)

        return self.PROMPT_TEMPLATE.format(topic=topic, comments_text=comments_text), fit_count

    async def _parse_arguments(self, response: str, likert_answers: List[int]) -> List[Argument]:
        arguments = []
        current_main = None
        current_subpoints = []
        current_indices = set()
        
        pattern = r'<ARGUMENTS>(.*?)</ARGUMENTS>'
        match = re.search(pattern, response, re.DOTALL)
        if not match:
            return arguments
            
        lines = match.group(1).strip().split('\n')
        
        for line in lines:
            line = line.strip()
            if not line:
                continue
                
            indices_match = re.search(r'\[source_indices: ([\d,\s]+)\]', line)
            indices = [int(idx.strip()) for idx in indices_match.group(1).split(',')] if indices_match else []
            
            content = re.sub(r'\[source_indices: [\d,\s]+\]', '', line).strip()
            
            if line.startswith('MAIN:'):
                if current_main is not None:
                    relevant_scores = self.get_relevant_scores(list(current_indices), likert_answers)
                    score_distribution = self.calculate_score_distribution(relevant_scores)
                    arguments.append(Argument(
                        main_point=current_main,
                        subpoints=current_subpoints,
                        score_distribution=score_distribution,
                        source_indices=list(current_indices)
                    ))
                
                current_main = content.replace('MAIN:', '').strip()
                current_subpoints = []
                current_indices = set(indices)
                
            elif line.startswith('SUB:'):
                subpoint = content.replace('SUB:', '').strip()
                current_subpoints.append(subpoint)
                current_indices.update(indices)
        
        # Add the last argument
        if current_main is not None:
            relevant_scores = self.get_relevant_scores(list(current_indices), likert_answers)
            score_distribution = self.calculate_score_distribution(relevant_scores)
            arguments.append(Argument(
                main_point=current_main,
                subpoints=current_subpoints,
                score_distribution=score_distribution,
                source_indices=list(current_indices)
            ))
            
        return arguments

    async def process_batch(self, comments: List[str], topic: str, likert_answers: List[int] = None) -> List[Argument]:
        '''
        Process a batch of comments and generate arguments.
        Returns a list of Argument objects and the number of comments that were used.
        '''
        indices = list(range(len(comments)))
        prompt, n_comments_used = await self._create_initial_prompt(comments, indices, topic) # gets the max number of comments that fit in the prompt
        response = await self.llm_provider.generate([Message(Role.USER, prompt)])
        
        # Parse arguments and calculate distributions in one step
        arguments = await self._parse_arguments(response.content, likert_answers if likert_answers else [])
        return arguments, n_comments_used

    async def format_arguments(self, arguments: List[Argument]) -> str:
        formatted_output = []
        for i, arg in enumerate(arguments, 1):
            formatted_output.append(f"\nArgument {i}:")
            formatted_output.append(f"Main point: {arg.main_point}")
            formatted_output.append(f"Source indices: {arg.source_indices}")
            
            if arg.subpoints:
                formatted_output.append("Supporting points:")
                for j, subpoint in enumerate(arg.subpoints, 1):
                    formatted_output.append(f"  {j}. {subpoint}")
            
            if arg.score_distribution:
                formatted_output.append("\nLikert Score Distribution:")
                for score_nominality, prevalence in enumerate(arg.score_distribution, 1):
                    formatted_output.append(f"  Score {score_nominality}: {prevalence:} answers")
            
            formatted_output.append("-" * 50)
        
        return "\n".join(formatted_output)

# %%
# TO DO: get the topic from the data source, now it is manually set
async def main():
    # Params
    n_comments = 400
    batch_size = 400
    topic = "Kun kunnan menoja ja tuloja tasapainotetaan, se on tehtävä mieluummin menoja karsimalla kuin veroja kiristämällä."  # Can be modified based on your needs

    # Config
    api_key = os.getenv("OPENAI_API_KEY")
    model="gpt-4o-2024-11-20"
    openai_provider = OpenAIProvider(api_key, model)    
    processor = ArgumentProcessor(openai_provider, batch_size)

    # Setup paths
    data_source_path = os.path.join(parent_dir, 'data', 'sources', 'kuntavaalit2021.csv')
    output_path = os.path.join(parent_dir, 'condensation', 'results','results_with_indices', 'version2.txt')

    # Read and prepare data
    df = pd.read_csv(data_source_path)

    # Choose a subset of comments to process
    question_index = 10
    explanation_column_name = f'q{question_index}.explanation_fi'
    likert_column_name = f'q{question_index}.answer'

    # Get comments and their original indices
    comment_mask = df[explanation_column_name].notna()
    comment_indices = df[comment_mask][explanation_column_name].index[:n_comments].tolist()
    comments = df.loc[comment_indices, explanation_column_name].tolist()
    
    # Get corresponding Likert scores
    likert_answers = df.loc[comment_indices, likert_column_name].tolist()
    
    # Process arguments
    arguments, n_comments_used = await processor.process_batch(
        comments=comments,
        topic=topic,
        likert_answers=likert_answers
    )

    print(f"Number of comments used: {n_comments_used} out of the attempted {n_comments}")
    
    # Format and save results
    formatted_args = await processor.format_arguments(arguments)

    # Print the comments for each argument
    for i, arg in enumerate(arguments):
        print(f"\nArgument {i+1}: {arg.main_point}")
        for idx in arg.source_indices:
            print(f"{idx}: {comments[idx]}")
    
    # Save to file
    with open(output_path, 'w', encoding='utf-8') as f:
        f.write(formatted_args)

await main()
# Out:
# Number of comments used: 390 out of the attempted 400
#
# Argument 1: Menojen karsiminen on parempi vaihtoehto kuin verojen korottaminen, sillä se voi vähentää kuntalaisten taloudellista kuormitusta ja lisätä kunnan houkuttelevuutta.
# 3: Mahdollisimman turhia menoja pitäisi karsia, ei tietenkään tärkeistä palveluista.
# 5: Menot tulojen mukaan.
# 6: Verojen korotus on mielestäni toimivampi ratkaisu. Kunnalla on harvoin sellaisia menoja, joista voisi karsia. Leikattavat menoerät liittyvät hyvin usein lapsiin, nuoriin, vanhuksiin sekä yhdistyksiin. Kun leikataan päivähoidosta tai opetuksesta, leikkaamme myös tulevaisuudesta. Seniorikuntalaisilla on oikeus hyvään ja turvalliseen elämään, johon kuuluvat tietyt verovaroin tuotetut palvelut. Yhdistykset tuottavat meidän vapaa-aikaamme toimintaa ja tapahtumia, joten niiden toiminnan lamauttaminen olisi kaikissa tilanteissa epäviisasta.
# 263: Toimintaa tehostamalla saadaan säästöjä aikaiseksi.
# 8: Kunnan tulee tarjota riittävät jo lainsäädännöllisetkin palvelut kuntalaisten hyvinvoinnin turvaamiseksi. Menojen ja tulojen tasapainottamisessa menojen karsinta ei ole välttämättä sama kuin toiminnan karsiminen. Esimerkiksi kuntien välinen yhteistyö, uusien teknologioiden hyödyntäminen, kunnan henkilöstön työhyvinvoinnin turvaaminen (vähäiset sairaspoissaolot, työmotivaatio, työn tuottavuus) ovat oleellisia välineitä kustannusten alentamiseksi. Tämä on jatkuvaa tasapainoilua ja tässä laittaisin ruksin keskelle, sillä molempia toimenpiteitä kuntataloudessa tarvitaan: menojen ja tulojen hallintaa.
# 267: Mitä menolla tarkoitetaan. Peruspalvelut eivät saa kärsiä
# 12: On elettävä suu säkkiä myöten. Pitäisi ennemmin keksiä uusia tuloja ja niitä syntyy vähemmän lisäverotuksella.
# 17: Ei ne suuret tulot, vaan pienet menot. Vanha totuus pätee tässäkin. Kaikista mieluiten taloutta tulee tasapainottaa investoimalla kunnan elinkeinoelämään sekä vetovoimaan eli houkuttelemalla kuntaan uusia työnantajia sekä asukkaita - ts. parantamalla tulopohjaa.
#
# Mikäli kuitenkin säästöjä olisi tehtävä, niin on hyvä pitää mielessä, että kunnan tehtävät ja palvelurakenne ovat viime vuosina muuttuneet. Näin ollen ensin tulisi tarkastella kunnan palveluita sekä prosesseja: Tehdäänkö varmasti oikeita ja vaikuttavia asioita, kustannustehokkaalla tavalla? Vai tehdäänkö vanhasta muistista vielä myös asioita, joita ei nykyisessä mallissa enää edes tulisi tehdä? Kohdennetaanko niukat resurssit oikeudenmukaisesti? Entä onko prosesseissa paljon hukkaa?
#
# Uskon, että ns "leanaamalla" on löydettävissä paljon säästöjä ilman, että palveluista joudutaan tinkimään - ja ilman, että veroja kiristetään. Kotkan veroprosentti on jo melko korkea ja vastustan kuntaverotuksen kiristämistä.
# 146: Riippuu mistä karsitaan. Mikäli vaakakupissa on palveluiden heikentäminen ja veron korotukset, ei palveluiden heikentäminen ole vaihtoehto. Koronan jälkeen tulee suuri tarve terveys- ja sosiaalipalveluille. Nämä on saatava hoidettua, tai niillä voi olla pitkävaikutteiset seuraukset.
# Mikäli menojen karsiminen onnistuu muutoin kuin henkilöstön tai palveluiden kustannuksella on se tietysti kannatettavaa.
# 20: Tehostettävaa ja kohdentamista riittää.
# 21: Juuri näin, kaikki menot tulee arvioida - jatkuvasti. Ei ole sellaista kunnan toimintoa, joka olisi tarpeellinen ikuisesti. Palvelun toteutustapaa ja taloutta on arvioitava jatkuvasti. Kaikkea ei tarvitse tehdä kunnan omana toimintana, usein yhteistyömalli kunnan ja yritysten tai kolmannen sektorin kanssa on toimiva ratkaisu. Osa kunnan palveluista on hoidettava omana toimintana, jos sitä ei ole kannattavaa toteuttaa yksitysellä palveluntarjoajalla.
# 25: Säästöjä tulee etsiä ennen verojen korotuksen miettimistä.  Tasapaino menojen ja tulojen suhteen on ensisijainen tavoite. Verot ovat jo Kotkassa melkoisen korkealla tasolla.
# 26: Riippuu mistä palveluista on kyse.
# 27: Kotkan kuntaveroprosentti on nyt 21,5 eli keskitasoa. Tarkalla taloudenpidolla ja suunnittelulla se voidaan pitää ennallaan. Kunnan lakisääteisistä tehtävistä ei voi karsia. Jos jostain syystä tulisi tilanne, että rahat eivät niihin riitä niin silloin on harkittava lainan, kunnan perimien maksujen ja veronkorotuksen välillä.
#
# 159: Kunnan menot ja tulot tulee olla tasapainossa. Jo korkeaa verotusta ei tule enää nostaa, vaan menoja tulee karsia tuloja vastaaviksi.
# 160: Ajan kuluessa kunnan toimintoihin on tullut uusia rönsyjä, jotka eivät enää ole sidoksissa alkuperäisen hyvinvointivaltion ajatukseen. vaan jotka lähinnä hyödyttävät niistä palkkansa saavia. Näistä rönsyistä säästäminen on syytä aloittaa.
# 33: Tällaisessa tilanteessa tulee lähtökohtaisesti tarkistaa ensin onko jotain palveluja tai toimintoja mahdollista kehittää, tehostaa tai järjestellä uudelleen säästöjen saavuttamiseksi. Tai onko mahdollisuutta kasvattaa tulopuolta muuten kuin verotuksella. Jos tämä ei riitä, on veroja tarvittaessa nostettava, tärkeiden palvelujen turvaamiseksi.
# 34: Kunnan on tehtävä uudistuksia, myös menoja karsittava kunnan tulotason mukaan
# 162: Joskus on kiristettävä vyötä ja hyvinä vuosina laitettava sukanvarteen. Veronkorotusten tie on mielestäni käyty loppuun tässä taloustilanteessa. Pitää löytyä muita ratkaisuja. Toimintoja tehostamalla ja luopumalla menoista sekä toiminnoista, jotka eivät ole kunnan kannalta oleellisia, pitää löytyä tasapaino veroja kiristämättä.
# 288: Menopuolella voidaan miettiä erilaisia tapoja järjestää palvelut.
# 41: Kunnalla on lakisääteiset palvelunsa jotka sen on pakko hoitaa. Sosiaali- ja terveyspalvelut vievät esim. Kotkassa suurimman osan budjetista ja niiden osuus ei muutu vaikka soteuudistus toteutuukin. Merkittäviä säästöjä on erittäin vaikeata löytää. Itse olen sitä mieltä, että kunnan tärkein tehtävä on tarjota palveluita ja hyvinvointia kuntalaisille. Luoda hyvät puitteet opiskeluun, yrittämiseen, perheen perustamiseen, hyvään vanhuuteen jne. Siksi niitä veroja kerätään.
# 44: Riippuu täysin käsillä olevasta aiheesta. Jos veroja lisäämällä taattaisiin nopeampia ja monipuolisempia mielenterveyspalveluita, olisin valmis maksamaan enemmän.
# 173: Turhanpäiväiset menot kuriin.
# 54: Välttämättömäksi katsottavat kunnan toiminnot, kuten peruskoulu ja lasten päivähoito, tulee aina säilyttää, mutta muissa palveluissa voitaneen tehdä leikkauksia pakon edessä. Verotuksen korottamista en näe kovin hyvänä ratkaisuna, koska sehän tarkoittaa samalla myös ihmisten ostovoiman heikkenemistä. Ja kun ostovoima heikkenee, palveluja ja hyödykkeitä myyvillä yrityksillä menee huonommin. Nämä ovat aina vähän kaksipiippuisia juttuja. Kun yhteen suuntaan kumartaa, toiseen suuntaan pyllistää...
# 56: Kotkan kaupungin rakenteellinen velkaongelma ei korjaannu verojen korotuksella. Kotkan resurssit tulee keskittää kaupungin ydintehtäviin eli perusasiat kuntoon koulut, peruspalvelut sekä infrastruktuuri. Niistä on leikattava mitkä eivät kuulu kaupungin ydintehtäviin esimerkiksi maahanmuutto. Maahanmuutosta päätetään myös kaupunginvaltuustossa, vaikka toisin väitetään.
# 57: Kaiken maksaminen jatkuvalla verojen korotuksilla on saavuttanut lakipisteensä. Nyt pitää laittaa "suu säkkiä myöten" ja karsia järkevällä tavalla kunnan menoja - ei veronkorotuksille.
# 61: Suomi on puhki verotettu jo valmiiksi, kyllä ensisijainen lähtökohta on sovittaa menot tuloihin.
# 62: Järkevässä talouspolitiikassa on myös osattava tasapainottaa kuluja mahdollisuuksien mukaan.
# 64: Talouden tasapainottaminen ja mielummin ylijäämäiseksi saaminen on lienee jokaisen kunnan tavoite pitkällä aikavälillä. Ensisijaisesti olisi puututtava ei välttämättömiin menoihin, kuin nostaa veroja.
# 321: Menoja pitää pyrkiä karsimaan mm. rakenteita ja toimintatapoja tarkastellen.
# 66: Verojen kiristäminen nykyisestään ei voi olla vaihtoehto, joten sitten menoja karsimalla.
# 195: Tehostamisen varaa on ihan varmasti ja rönsyjä voi leikata. Näin tehdään yksityiselläkin puolella.
# 79: En hyväksy jo valmiiksi alimitoitettujen sosiaali- ja terveyspalvelujen karsimista säästön nimissä, nämä iskevät rankimmin muutenkin huono-osaisiin.
# 83: Tässä on tärkeää, mistä säästetään. Paras säästökohde ovat turhat kiinteistöt.
# 344: Lakisääteiset tehtävät kuitenkin turvattava
# 96: Pitää elää "suu säkkiä myöten" jos ei ole mahdollista lisätä tuloja muuten kuin verotuksella. Ensisijaiset toiminnot (terveys-, koulutus-, pelastus- ja infrapalvelut) tulee ylläpitää ja karsia muista vähemmän tärkeistä.
# 97: Kunnan toimintojen tehostaminen niin johdon kuin tekijäportaan osalla olisi hyvä keino.
# 104: Omalla alueellani nimenomaan menot ja niiden perusteet ovat ongelmallisia, tuhlailu turhuuksiin ei vaan toimi, järki käteen niin verotkaan eivät nouse.
# 361: Pelkkä menojen karsiminen johtaa helposti juustohöyläperiaatteeseen, mikä vie toimivilta palveluilta pohjan. Kuntatalouden tasapainotus pitäisi tehdä järkeistämällä toimintoja.
# 108: Kunnan on säilytettävä kattavat sosiaali- ja terveyspalvelut sekä laadukkaat koulutus- ja kulttuuripalvelut kuntalaisille. Siinä vaiheessa, kun menoja on vaikea karsia näiden palveluiden tuottamiseksi on harkittava verojen kiristämistä.
# 113: Tietty palvelutaso on kunnissa aina turvattava ja niiden osalta ei leikkauksia saa tehdä vaan tarvittaessa ne on turvattava vaikka veroäyrin nostolla,
# 241: Tietyistä peruspalveluista ei voi tinkiä, erityisesti päivähoito, koulutus, perusterveydenhoito ja vanhusten palvelut ovat sellaisia.
# 243: Tästä syystä kannatan mm. perustuloa, joka on yksinkertaisesti järkevää nykyisen kalliin lomake- ja byrokratiahimmelin ylläpitämisen sijasta. Mutta: menoja ei pidä karsia vanhanaikaisilla leikkausperiaatteilla vaan kuntien hallinnoista tulee etsiä lisää työtehoa työtapoja ja prosesseja kehittämällä, mikä ratkaisuvaihtoehto hämmästyttävästi loistaa poissaolollaan julkisella puolella.
# 378: Menojen vähentäminen pitäisi tehdä virkamieskuluista.
# 379: Suomessa on lähes maailmanennätysmäärä hallintoa näin pientä maksavaa kansaa varten. Hallintoa on kevennettävä.
# 125: Turhaa hallintoa karsittava.
#
# Argument 2: Korkean verotuksen negatiiviset vaikutukset, kuten kuntalaisten ostovoiman heikentyminen ja kunnan houkuttelevuuden väheneminen, tekevät veronkorotuksista huonon vaihtoehdon.
# 10: Kotkassa veroprosenttia on nostettu vuonna 2017 ja se on nyt 21,5 %. Tämä on isompi kuin Kotkan lähikunnissa. Veroprosentin nosto ei minusta ole kestävä ratkaisu kunnan kustannusten hallinnassa. Koronakriisi ja sen jälkihoito voi luoda nostopainetta.
# 266: Verotus tulee pystyä pitämään houkuttelevalla tasolla. Kustannustehokkuus tulee olla yksi keskeisistä ohjenuorista päätöksenteossa, vaan ei ainoa. Kustannustehokkuutta ei voida luoda vain laatua laskemalla, vaan toteuttamalla järkeviä ja tehokkaita ratkaisuja. Meidän on pystyttävä pitämään kiinni keskeisistä vetovoima tekijöistämme hyvät koulutuspalvelut ja lähiluonto sekä matalat asumiskustannukset.
# 13: Kotkan veroprosentti on jo riittävän korkealla tasolla, mutta menoleikkauksetkin ovat haasteellisia toteuttaa. Jos pitää säästää, niin sitten säästetään tasaisesti kaikkialta. Kunnan vetovoimaisuus yritysten sijoittumiseen paikkakunnalle olisi kuitenkin pyrittävä pitämään mahdollisimman korkealla tilanteesta huolimatta.
# 14: Veronkorotukset ovat aina vain väliaikaisia toimenpiteitä kaupungin talouden tasapainottamiseksi eikä poista varsinaista ongelmaa. Kaupungin talouden kääntäminen kestävälle pohjalle edellyttää liike- elämän ja ihmisten aktiivisuutta. Korkea kunnallisvero ei myöskään houkuttele uusia veronmaksajia kaupunkiin. Tiukassa tilanteessa on varoja kohdennettava kaupungin toiminnan ja asukkaiden hyvinvoinnin kannalta tärkeimpiin toimintoihin.
#
# 270: Molempia keinoja tarvitaan. Ja muitakin, on se vaan sen verran vaikea tuo kuntatalouden hoito.
# 300: Me emme voi enää korottaa veroja – ei kunta- eikä valtiotasolla, ja hyvin pian meillä on mahdollisesti myös maakunta-/hyvinvointialueiden verotus. Veronkorotukset eivät ole kestävä tie nyt eikä tulevaisuudessa: veroja maksavat ikäryhmät pienenevät ja palveluja käyttävät kasvavat.
# 45: Kotkassa veroprosentti on jo nyt aika korkea, menojen karsinta pitää miettiä tasapuolisesti.
# 176: Veron korotukset karkoittaa ihmiset ja yritykset. Kunnan taloutta pitää tasapainottaa siten että turhista hankeista pidättäydytään ja tarkoin harkitaan mihin rahkeet rittävät.
# 48: Omassa kunnassa kuntaveroprosentti on jo niin korkea, että nostomahdollisuuksia ei oikeastaan ole. Kuntien on varmasti mietittävä palveluiden kohdalla, millaisia asioita tarjotaan ja miten. Mielestäni ratkaisut tulee kuitenkin tehdä palvelukohtaisesti ja valita toimivat tavat. On palveluja, joista ei voida karsia ja siinä kohtaa tulisi valita mielummin verojen korottaminen.
# 178: Veronkorotuksilla ongelmat siirretään vain tulevaisuuteen.
# 52: Veroja kiristämällä vähennetään kuntalaisten ostovoimaa ja siten vähennetään kunnan elinvoimaisuutta.
# 56: Kotkan kaupungin rakenteellinen velkaongelma ei korjaannu verojen korotuksella. Kotkan resurssit tulee keskittää kaupungin ydintehtäviin eli perusasiat kuntoon koulut, peruspalvelut sekä infrastruktuuri. Niistä on leikattava mitkä eivät kuulu kaupungin ydintehtäviin esimerkiksi maahanmuutto. Maahanmuutosta päätetään myös kaupunginvaltuustossa, vaikka toisin väitetään.
# 187: Veronkiristykset vievät työpaikkoja, kurittavat asukkaita ja yrityksiä. Aiheuttavat pois muuttoa kaupungista, missä verot on korkealla. Kiinnostavuus vähenee ja elinvoimaisuus heikkenee.
# 65: Veroprosenttia ei pidä nostaa. Tämä vaikeuttaa kotitalouksien asemaa vähentämällä käytettävissä olevan rahan määrää. Korkea veroprosentti ei myöskään lisää alueen vetovoimaisuutta.
# 71: Verotus on hyvä pitää työntekoon, yrittäjyyteen ja investointeihin kannustavana. Tätä kautta me saamme kasvatettua verotulot hyvinvointiyhteiskunnan palveluihin ja sosiaaliturvaan. Kannustava verotus ruokkii talouskasvua ja työllisyyttä. Ei kiristetä verotusta”
# 76: Tietyn asteinen talouskuri on oltava. Veronkorotukset eivät houkuttele uusia asukkaita, saati yrityksiä sijoittumaan Kotkaan. Jo valmiiksi muuttotappiokuntana kaupungin on löydettävä muita vaihtoehtoja talouden tasapainottamiseksi. Vetovoimaa on kasvatettava, eikä dumpattava alaspäin.
# 349: Yksistään veroja korottamalla emme voi säilyttää kaikkia nykyisiä palveluita ja koko palveluverkostoa (väestö ikääntyy ja sairastavuus kasvaa). Suomi tarvitsee mm. hyvin valmistellun ja toteutetun sote-uudistuksen.
# 98: Verotus osuu sekä pien- että suurituloisiin mutta leikkaukset usein erityisesti pientuloisiin, koska hyvätuloisilla on mahdollisuus yksityisiin palveluihin. Päättäjien tehtävänä on löytää rahoituskeinot joilla palvelut ja sosiaalietuudet pystytään kattamaan. Leikkaukset ja köyhyys tulevat entistä kalliimmaksi yhteiskunnalle pahoinvoinnin ja sairauksien lisääntymisenä.
# 234: Verotus on kilpailutekijä, ja Kouvolassa se on jo sellaisella tasolla että ihan kevyin perustein ei kiristykseen olisi varaa.
# 113: Tietty palvelutaso on kunnissa aina turvattava ja niiden osalta ei leikkauksia saa tehdä vaan tarvittaessa ne on turvattava vaikka veroäyrin nostolla,
# 370: Verojen kiristäminen kohdistuu myös pienituloisiin eli heikentää heidän asemaansa eniten.
# 373: Kuntien talous on vahvasti alijäämäinen ja Kuopiossa rakenteellinen alijäämä on noin 20 miljoonaa. Tätä ei korjata veroja nostamalla, vaan rakenteita muuttamalla. Olen kirjoittanut aiheesta blogin https://www.miiaef.fi/kuntataloudesta/ . Kunnille ei voida enää osoittaa enempää lakisääteisiä toimintoja.
#
# Argument 3: Menoleikkaukset eivät saa heikentää kuntalaisten hyvinvointia tai peruspalveluiden saatavuutta.
# 6: Verojen korotus on mielestäni toimivampi ratkaisu. Kunnalla on harvoin sellaisia menoja, joista voisi karsia. Leikattavat menoerät liittyvät hyvin usein lapsiin, nuoriin, vanhuksiin sekä yhdistyksiin. Kun leikataan päivähoidosta tai opetuksesta, leikkaamme myös tulevaisuudesta. Seniorikuntalaisilla on oikeus hyvään ja turvalliseen elämään, johon kuuluvat tietyt verovaroin tuotetut palvelut. Yhdistykset tuottavat meidän vapaa-aikaamme toimintaa ja tapahtumia, joten niiden toiminnan lamauttaminen olisi kaikissa tilanteissa epäviisasta.
# 7: Tietynlaiset tilanteet vaativat erilaisia toimia. Esim. jos opetus- ja koulutuspalveluista karsittaisiin, olisin valmis verokiristyksiin.
# 146: Riippuu mistä karsitaan. Mikäli vaakakupissa on palveluiden heikentäminen ja veron korotukset, ei palveluiden heikentäminen ole vaihtoehto. Koronan jälkeen tulee suuri tarve terveys- ja sosiaalipalveluille. Nämä on saatava hoidettua, tai niillä voi olla pitkävaikutteiset seuraukset.
# Mikäli menojen karsiminen onnistuu muutoin kuin henkilöstön tai palveluiden kustannuksella on se tietysti kannatettavaa.
# 155: Kokemus on osoittanut, että menoleikkaukset kohdistuvat usein jo valmiiksi heikossa asemassa oleviin, eivät kuitenkaan tuo riittäviä säästöjä tai aiheuttavat ennakoimattomia (tai huomiotta jätettyjä) menoja toisaalla. Verotus on ainakin jossain määrin reilumpi keino.
# 38: Liika säästäminen aiheuttaa lisäkuluja kunnalle, joten tarvittaessa olen valmis vähän nostamaan kuntaveroa, jotta kuntalaisten hyvinvointi ei kärsi. Yleensä heikoimmassa asemassa olevat tarvitsevat eniten kunnan palveluja, ja jos palveluja ei tuoteta riittävästi niin lisääntyy eri asukasryhmien eria-arvoisuus entisestään.
# 42: Menojen karsinta helposti kohdistuu heikompiosaisiin. Näiden vaihtoehtojen välillä olisi löydettävä järkevä tasapaino.
# 43: Verotusta ei voida enää kiristää. On mietittävä mitkä ovat ne palvelut jotka kunnalle ovat tärkeitä. Varsinkaan varhaiskasvatuksesta ja peruskoulusta ei saa leikata.
# 48: Omassa kunnassa kuntaveroprosentti on jo niin korkea, että nostomahdollisuuksia ei oikeastaan ole. Kuntien on varmasti mietittävä palveluiden kohdalla, millaisia asioita tarjotaan ja miten. Mielestäni ratkaisut tulee kuitenkin tehdä palvelukohtaisesti ja valita toimivat tavat. On palveluja, joista ei voida karsia ja siinä kohtaa tulisi valita mielummin verojen korottaminen.
# 49: Menoleikkaukset tarkoittavat käytännössä leikkauksia palveluihin, jotka ovat osalle kuntalaisista elintärkeitä. Koska palveluiden leikkaamisella on niin suuri vaikutus kuntalaisten elämään, tulee siihen turvautua vasta viimeisenä keinona.
# 79: En hyväksy jo valmiiksi alimitoitettujen sosiaali- ja terveyspalvelujen karsimista säästön nimissä, nämä iskevät rankimmin muutenkin huono-osaisiin.
# 81: Kunnan tehtävä on huolehtia laissa määritellyistä peruspalveluista ja on tärkeää tehdä töitä sen eteen, että voimme tulevaisuudessakin nauttia laadukkaista palveluista Kotkassa (mm. päiväkodit, koulut, terveyspalvelut ja vanhustenhoito). Nykyinen kyvyttömyys tehdä rohkeita ratkaisuja ja parempaa politiikkaa ovat johtaneet tähän tilanteeseen, että joudumme miettimään palveluiden karsimista tai veronkorotuksia. Veronkorotuksilla lakaistaan tämän päivän ongelmat vain tulevaisuuteen, koska ne laskevat Kotkan vetovoimaisuutta ja joudumme lähivuosina miettimään samoja ongelmia uudestaan. Tärkein on pyrkiä tekemään ratkaisuja, joilla parannamme kaupungin elinkeinopolitiikkaa erityisesti PK-yritysten kannalta. Pienyritykset työllistävät valtavan määrän ihmisiä ja siihen kannattaa myös Kotkassa panostaa, jotta ihmiset uskaltavat ja haluavat yrittää. Tätä kautta myös verotuloja syntyy enemmän ja pystymme tulevaisuudessa tarjoamaan laadukkaampia palveluja!
# 344: Lakisääteiset tehtävät kuitenkin turvattava
# 219: En toivo suuria veronkorotuksia, mutta mielummin veronkorotuksia kuin palveluiden karsimista tai laadun heikentämistä. Johonkin pisteeseen asti on toki taloustilanteen pakottaessa arvioitava myös sopeutusmahdollisuuksia ja  asioiden priorisointia entistä vahvemmin. Välttämättömistä sote-palveluista tai esimerkiksi lasten opetuksesta ei tulisi eikä ole mahdollista mielestäni karsia.
# 353: Palveluista, jotka liittyvät kuntalaisten hyvinvointiin ja terveyteen, ei tule karsia. Moni arkeen liittyvä palvelu tai toiminta kuten liikunta-, sosiaali-, terveys-, kulttuuripalvelut tukevat kuntalaisten hyvinvointia. Näistä palveluista karsiminen lisää kuntalaisten eriarvoisuutta ja lisää pitkällä aikavälillä palveluiden kysyntää. Näin se tulee kalliimmaksi.
# 98: Verotus osuu sekä pien- että suurituloisiin mutta leikkaukset usein erityisesti pientuloisiin, koska hyvätuloisilla on mahdollisuus yksityisiin palveluihin. Päättäjien tehtävänä on löytää rahoituskeinot joilla palvelut ja sosiaalietuudet pystytään kattamaan. Leikkaukset ja köyhyys tulevat entistä kalliimmaksi yhteiskunnalle pahoinvoinnin ja sairauksien lisääntymisenä.
# 99: Leikkauspolitiikan kanssa tässä maassa olisi varmasti yleisellä tasolla hyvä pitää taukoa.
# 356: Tuloja ja menoja on pyrittävä tarkastelemaan niin, että välttämättömät ja ongelmia ennaltaehkäisevät palvelut turvataan ja vähemmän tärkeiksi katsotuista menoista leikataan. Mikäli tämä ei riitä, on voitava harkita myös maltillista verojen korotusta.
# 102: Julkispalveluja ei saa enää horjutta.On jo nyt huonossa jamassa.Mikä olisi se meno?Ei koulut,varhaiskasvatus,vanhustenpalvelut jne.Rakentaminen voisi olla ainut tai infran supistus
# 107: Monet palvelut ovat jo nyt niin tiukoilla, ettei niistä ole varaa karsia. Esimerkiksi lapsiin ja nuoriin liittyvät palvelut ovat satsaus tulevaisuuteen ja niistä ei tule tinkiä enää yhtään.
# 108: Kunnan on säilytettävä kattavat sosiaali- ja terveyspalvelut sekä laadukkaat koulutus- ja kulttuuripalvelut kuntalaisille. Siinä vaiheessa, kun menoja on vaikea karsia näiden palveluiden tuottamiseksi on harkittava verojen kiristämistä.
# 113: Tietty palvelutaso on kunnissa aina turvattava ja niiden osalta ei leikkauksia saa tehdä vaan tarvittaessa ne on turvattava vaikka veroäyrin nostolla,
# 241: Tietyistä peruspalveluista ei voi tinkiä, erityisesti päivähoito, koulutus, perusterveydenhoito ja vanhusten palvelut ovat sellaisia.
#
# Argument 4: Kuntatalouden tasapainottaminen vaatii pitkäjänteistä suunnittelua ja sekä menojen että tulojen hallintaa.
# 8: Kunnan tulee tarjota riittävät jo lainsäädännöllisetkin palvelut kuntalaisten hyvinvoinnin turvaamiseksi. Menojen ja tulojen tasapainottamisessa menojen karsinta ei ole välttämättä sama kuin toiminnan karsiminen. Esimerkiksi kuntien välinen yhteistyö, uusien teknologioiden hyödyntäminen, kunnan henkilöstön työhyvinvoinnin turvaaminen (vähäiset sairaspoissaolot, työmotivaatio, työn tuottavuus) ovat oleellisia välineitä kustannusten alentamiseksi. Tämä on jatkuvaa tasapainoilua ja tässä laittaisin ruksin keskelle, sillä molempia toimenpiteitä kuntataloudessa tarvitaan: menojen ja tulojen hallintaa.
# 270: Molempia keinoja tarvitaan. Ja muitakin, on se vaan sen verran vaikea tuo kuntatalouden hoito.
# 17: Ei ne suuret tulot, vaan pienet menot. Vanha totuus pätee tässäkin. Kaikista mieluiten taloutta tulee tasapainottaa investoimalla kunnan elinkeinoelämään sekä vetovoimaan eli houkuttelemalla kuntaan uusia työnantajia sekä asukkaita - ts. parantamalla tulopohjaa.
#
# Mikäli kuitenkin säästöjä olisi tehtävä, niin on hyvä pitää mielessä, että kunnan tehtävät ja palvelurakenne ovat viime vuosina muuttuneet. Näin ollen ensin tulisi tarkastella kunnan palveluita sekä prosesseja: Tehdäänkö varmasti oikeita ja vaikuttavia asioita, kustannustehokkaalla tavalla? Vai tehdäänkö vanhasta muistista vielä myös asioita, joita ei nykyisessä mallissa enää edes tulisi tehdä? Kohdennetaanko niukat resurssit oikeudenmukaisesti? Entä onko prosesseissa paljon hukkaa?
#
# Uskon, että ns "leanaamalla" on löydettävissä paljon säästöjä ilman, että palveluista joudutaan tinkimään - ja ilman, että veroja kiristetään. Kotkan veroprosentti on jo melko korkea ja vastustan kuntaverotuksen kiristämistä.
# 19: Vastuullinen kuntatalouden hoito voi olla ja sen tulee olla muutakin kuin välittömiä sopeutustoimia, ts. menojen leikkauksia ja/tai verojen korotuksia.
# Olen sitoutunut löytämään talouskasvua ja työllisyyttä tukevia rakenneuudistuksia siten, että veroja ei tarvitse nostaa ja menoleikkaukset voidaan minimoida. Ennen kaikkea tarvitaa yrittäjyyttä ja työn tekemistä tukevie toimenpiteitä, jotka tuottavat verotuloja kunnan menojen kattamiseen.
#
# 28: Tulot ja menot saatava tasapainoon ja kumpaakin keinoa voidaan käyttää. Parhain keino on synnyttää lisää työtä ja verotuloja.
# 286: Mielestäni kuntataloudessa olisi paljon kehitettävää palveluiden tuottavuudessa. Kehittämällä omaa toimintaa parannamme tuottavuutta ja veronkorotuksiin ei tarvitse mennä.  Palveluiden järjestämistapojen kehittäminen, päällekkäisten tehtävien karsiminen. Mielestäni verojen korottamisen kautta ei saada lisättyä toiminnan tehokkuuta ja tuottavuutta. Myös kolmannen sektorin mukaan ottaminen palveluiden järjestämiseen on huomioitava vaihtoehto
# 33: Tällaisessa tilanteessa tulee lähtökohtaisesti tarkistaa ensin onko jotain palveluja tai toimintoja mahdollista kehittää, tehostaa tai järjestellä uudelleen säästöjen saavuttamiseksi. Tai onko mahdollisuutta kasvattaa tulopuolta muuten kuin verotuksella. Jos tämä ei riitä, on veroja tarvittaessa nostettava, tärkeiden palvelujen turvaamiseksi.
# 299: Kaupungin alijäämän korjaamiseen verojen korotukset eivät saa olla ainoa vaihtoehto.
#
# Palveluverkkoa pitää tarkastella jatkuvasti, jotta kaupungin toiminnot kehittyvät ja pysyvät ”ajanhermolla”. Tämä ei välttämättä tarkoita palveluiden karsimista, vaan uusien toimintamallien löytämistä palveluiden toteuttamiseen. Digitalisaatio on tässä avainasemassa tulevaisuudessa.
#
# 46: Tasapainotus on tehtävä mahdollisimman hyvin ja pitkällä aikajänteellä.
# 182: Ensimmäisenä toimenpiteenä tulee olla menojen tarkastelu ja niiden saattaminen järkevälle tasolle. Vasta sen jälkeen tulee tehdä mahdollisia veronkorotuksia.
# 320: Tärkeää on uusien työpaikkojen luominen ja siten veropohjan laajentaminen, jolloin verotusta ei tarvitse kiristää.
# 69: Tämä on turhan yksipuolistava väite. Kunnan taloutta pitää hoitaa sellaisella suunnitelmallisuudella ja resurssien kohdentamisella, ettei tähän joko tai -tilanteeseen jouduta. Jos jonkun äkillisen katastrofitilanteen, kuten merkittävän työllistäjän poistumisen kaltainen tilanne, eteen jouduttaisiin, silloin hätätilanteessa pitää miuluummin nostaa veroja kuin leikata menoja. Yleensä menoleikkaukset (ja enenevässä määrin soteuudistuksen takia) kohdistetaan erityisesti heikoimmassa asemassa olevien kuntalaisten palveluihin. Koska esimerkiksi Kotkassa on jo siirrytty Kymsoteen, niin meillä lähes ainoa mittava leikkauskohde kohdistuisi lapsiin eli varhais- ja perusopetukseen. Kaikenlaisesta kulttuurista ja liikunnasta leikkauksia unelmoivat ovat tyhjän päällä, sillä niistä leikkauksista ei kerry paljon mitään säästöjä.
# 206: Tasapaino täytyy talouteen löytyä. Verotus ei voi olla ainoa keino.
# 80: Kestävä tapa verotulojen kasvattamiseen ja edelleen talouden tasapainottamiseen on työllisyysasteen nostaminen ja työn tuottavuuden parantaminen.
# 345: Molemmat keinot tarvitaan käyttöön. Vastuullisten päättäjien on huolehdittava siitä, että palvelut tuotetaan tehokkaasti ja todelliseen tarpeeseen, mutta esimerkiksi kysynnän kasvaessa voi olla tarpeen tarkistella myös tulopuolta - eli verotusta.
# 225: Menoja voi kiristää muuttamalla toimintamalleja ja ottamalla käyttöön joustavia palvelukonsepteja. Kaikkia ei kannata enää tehdä "niinkuin ennen".
# 361: Pelkkä menojen karsiminen johtaa helposti juustohöyläperiaatteeseen, mikä vie toimivilta palveluilta pohjan. Kuntatalouden tasapainotus pitäisi tehdä järkeistämällä toimintoja.
# 364: Tilanne oli vaikea ja korona on tuonut lisää haasteita taloudelle. Veronkorotus ei ole hyvä vaihtoehto. Uskon, että löytyy erilaisia lähestymistapoja elinvoiman ja verotulojen kasvattamiseen ilman veronkorotusta. Esimerkiksi korkeampi työllisyysaste vahvistaa taloutta. Jos jokaisella työkykyisellä olisi töitä, niin kunnan taloudellinen tilanne olisi parempi.
# 369: Minusta varsinkin näin koronakurimuksen jäljiltä kuntien tulisi säilyttää jo olemassa olevat palvelunsa ja tehostaa niitä varsinkin lapsiperheille, nuorille, vanhuksille sekä muille koronan takia vaikeuksiin joutuneille ihmisille.
# Painopiste pitäisi laittaa palvelujen tuottamistapojen ja rakenteiden uudistamiseen. Kummatkin vaihtoehdot on kuitenkin säilytettävä tarpeen tullessa käytössä.
# 115: Tärkeintä on saada lisää työpaikkoja ja siten veronmaksajia.
# 371: Löysiä pitää kyetä karsimaan, jotta saadaan taattua peruspalvelut. Nämä vaativat korkean verotuksen. Pääasia olisi kuitenkin se, että veropohjaa saadaan kasvatettua, jolloin leikkauksia tai veronkorotuksia ei tarvitsisi tehdä.
# 117: Pelkkä juustohöylän käyttö ei riitä vaan on uskallettava katsoa syvemmälle, niin palveluverkkoihin kuin organisaatiorakenteeseenkin.
#
# Argument 5: Kuntatalouden tasapainotus ei ole joko-tai-kysymys, vaan molempia keinoja - menojen karsimista ja veronkorotuksia - voidaan käyttää harkiten.
# 1: Pitää katsoa mikä toimenpide kulloinkin on järkevää toteuttaa.
# 258: Palvelujen tehostaminen, sopeuttaminen ja menojen karsiminen ovat tänäkin vuonna kaupungilla työn alla. Loputon karsiminenkaan ei kuitenkaan ole aina paras vaihtoehto, joten on myös arvioitava milloin kohtuullinen veronkiristys on väistämätön toimenpide. Verotusta ei tule nostaa kevyin perustein, sillä Kuhmon verotus on jo Kainuun korkeimpia.
# 201: Kuitenkin palvelut tärkeitä ja mahdollisesti verojakin kiristettävä jossain tilanteessa.
# 202: Kouvolassa kunnallisvero on jo valtakunnallisesti verraten korkeahko. Myös kipeitä leikkauksia on jouduttu tekemään ja karsimaan mm. kouluverkkoa. Asia ei ole niin mustavalkoinen, ratkaisuja tulee miettiä aina tapaus kerrallaan
# 330: Voidaan myös karsia menoja, mutta täytyy katsoa harkiten mistä karsitaan. Ei ainakaan peruspalveluista.
# 270: Molempia keinoja tarvitaan. Ja muitakin, on se vaan sen verran vaikea tuo kuntatalouden hoito.
# 86: Pidemmällä aikajanalla verotus on toimivampi vaihtoehto. Tasapainotus ja sen toteuttaminen tulee selvittää tarkasti ennen päätöksen tekoa, tarvittavista palveluista ei saa leikata.
# 343: Molempia tarvitaan, jos kunta kriisiytyy
# 151: Tottakai löysät on otettava menoista pois ja kaikki vaihtoehdot käytävä läpi ennen veronkorotusta. Maltilliset veronkorotukset voivat kuitenkin pakkotilanteissa tulla kysymykseen.
# 219: En toivo suuria veronkorotuksia, mutta mielummin veronkorotuksia kuin palveluiden karsimista tai laadun heikentämistä. Johonkin pisteeseen asti on toki taloustilanteen pakottaessa arvioitava myös sopeutusmahdollisuuksia ja  asioiden priorisointia entistä vahvemmin. Välttämättömistä sote-palveluista tai esimerkiksi lasten opetuksesta ei tulisi eikä ole mahdollista mielestäni karsia.
# 31: Molempia keinoja tarvitaan - ei ole kyse joko tai asiasta.
# 222: Turhia menoja karsimalla ja mahdollisia tuloja hyödyntämällä pidetään kunnan asukkaat tyytyväisinä, kuin sillä, että veroja kiristetään jatkuvasti.
# Menojen karsimisessa pitää myöskin osata tasapainotella siten, että yhdeltä ryhmältä ei karsita palveluita/etuuksia, vaan niitä tasapainotetaan niin, ettei kukaan ryhmä kärsi toimenpiteistä.
# 223: Mielestäni kaikki vaihtoehdot täytyy olla käytettävissä, kun etsitään keinoja tasapainottaa talous ja löytää kestävän kasvun ura. Paras vaihtoehto löytyy todennäköisesti näitä molempia yhdistelemällä.
